# %%
def fun(i,n):
    if i>3:
        return
    print('mihir')
    fun(i+1,n)

# %%
fun(1,5)
# Out:
# mihir
# mihir
# mihir

# %%
def fun(i,n):
    if i>n:
        return
    print(i)
    fun(i+1,n)

# %%
fun(1,5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def fun(i,n):
    if i<1:
        return
    print(i)
    fun(i-1,n)

# %%
fun(1,5)
# Out:
# 1
