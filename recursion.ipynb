# %%
def fun(i,n):
    if i>3:
        return
    print('mihir')
    fun(i+1,n)

# %%
fun(1,5)
# Out:
# mihir
# mihir
# mihir

# %%
def fun(i,n):
    if i>n:
        return
    print(i)
    fun(i+1,n)

# %%
fun(1,5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def fun(i,n):
    if i<1:
        return
    print(i)
    fun(i-1,n)

# %%
fun(9,9)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %%
#backtracking
def fun(i,n):
    if i<1:
        return
    fun(i-1,n)
    print(i)

# %%
fun(5,5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def fun(i,n):
    if i>n:
        return
    fun(i+1,n)
    print(i)

# %%
fun(1,5)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
k=int(input('enter a number'))
s=0
for i in range(1,k+1):
    s+=i
print(s)
# Out:
# 15

# %%
n=int(input())
print(n*(n+1)//2)
# Out:
# 15

# %%
n=int(input())
fact=1
for i in range(1,n+1):
    fact*=i
print(fact)#optimal solution
# Out:
# 1

# %%
def factorial(n):
    if n==0:
        return 1
    return n*factorial(n-1)#o(n) space and time due to stack space worst case

# %%
factorial(5)
# Out:
# 120

# %%
arr = [1,2,3,4,5]
arr[:]=arr[::-1]
print(arr)
# Out:
# [5, 4, 3, 2, 1]

# %%
arr = [1,2,3,4,5]
arr=arr[::-1]
print(arr)
# Out:
# [5, 4, 3, 2, 1]

# %%
arr=list(map(int,input().split()))
print(arr[::-1])#not optimal solution as it takes o(n) space and time
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
arr=list(map(int,input().split()))
l,r=0,len(arr)-1
while l<r:
    arr[i],arr[r]=arr[r],arr[i]
    l+=1
    r-=1
print(arr)#optimal solution as it takes o(1) space and o(n) time
# Out:
# [3, 2, 1]

# %%
n=input('enter string')
l,r=0,len(n)-1
while l<r:
    if n[l]==n[r]:
        l+=1
        r-=1
    else:
        print('not palindrome')
        break
else:
    print('palindrome')
#optimal solution as it takes o(1) space and o(n) time
# Out:
# not palindrome
